# %%
# 1. Environment Setup and Data Loading
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df = pd.read_excel(r"esg_fund_data.xlsx")
print("Data loaded successfully. Data shape:", df.shape)
df.head()
# Out:
# Data loaded successfully. Data shape: (5772, 105)
#                    Fund profile: Fund name Fund profile: Tickers  \
# 0  1290 Avantis U.S. Large Cap Growth Fund          TNRAX, TNXIX
# 1         1290 Essex Small Cap Growth Fund   ESCFX, ESCJX, ESCKX
# 2      1290 GAMCO Small/Mid Cap Value Fund   TNVAX, TNVIX, TNVRX
# 3                1290 Retirement 2025 Fund                 TNJIX
# 4                1290 Retirement 2030 Fund                 TNKIX
#
#   Fund profile: Asset manager Fund profile: Target date  \
# 0                  1290 Funds                       NaN
# 1                  1290 Funds                       NaN
# 2                  1290 Funds                       NaN
# 3                  1290 Funds                         Y
# 4                  1290 Funds                         Y
#
#   Fund profile: Category group Fund profile: Sustainability mandate  \
# 0             U.S. Equity Fund                                  NaN
# ...

# %%
# 2. Data Overview
print("Columns:", df.columns.tolist())
# Out:
# Columns: ['Fund profile: Fund name', 'Fund profile: Tickers', 'Fund profile: Asset manager', 'Fund profile: Target date', 'Fund profile: Category group', 'Fund profile: Sustainability mandate', 'Fund profile: US-SIF member', 'Fund profile: Oldest shareclass inception date', 'Fund profile: Portfolio holdings as-of date', 'Fund profile: Fund net assets', 'Fund profile: Percent rated', 'Fossil Free Funds: Fossil fuel grade', 'Fossil Free Funds: Fossil fuel holdings, count', 'Fossil Free Funds: Fossil fuel holdings, weight', 'Fossil Free Funds: Fossil fuel holdings, asset', 'Fossil Free Funds: Coal industry, count', 'Fossil Free Funds: Coal industry, weight', 'Fossil Free Funds: Coal industry, asset', 'Fossil Free Funds: Oil / gas industry, count', 'Fossil Free Funds: Oil / gas industry, weight', 'Fossil Free Funds: Oil / gas industry, asset', 'Fossil Free Funds: Fossil-fired utilities, count', 'Fossil Free Funds: Fossil-fired utilities, weight', 'Fossil Free Funds: Fossil-fired utilitie
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5772 entries, 0 to 5771
# Columns: 105 entries, Fund profile: Fund name to Tobacco Free Funds: Tobacco-promoting entertainment company, asset
# dtypes: float64(35), int64(52), object(18)
# memory usage: 4.6+ MB

# %%
df.describe(include='all')
# Out:
#                         Fund profile: Fund name Fund profile: Tickers  \
# count                                      5772                  5651
# unique                                     5772                  5651
# top     1290 Avantis U.S. Large Cap Growth Fund          TNRAX, TNXIX
# freq                                          1                     1
# mean                                        NaN                   NaN
# std                                         NaN                   NaN
# min                                         NaN                   NaN
# 25%                                         NaN                   NaN
# 50%                                         NaN                   NaN
# 75%                                         NaN                   NaN
# max                                         NaN                   NaN
#
#        Fund profile: Asset manager Fund profile: Target date  \
# count                         5772                       364
# ...

# %%
# 3. Data Cleaning
# 3.1 Simplify Column Names (Simple snake_case)
simple_mapping = {
    "Fund profile: Fund name": "fund_name",
    "Fund profile: Tickers": "tickers",
    "Fund profile: Asset manager": "asset_manager",
    "Fund profile: Target date": "target_date",
    "Fund profile: Category group": "category",
    "Fund profile: Sustainability mandate": "sustainability_mandate",
    "Fund profile: US-SIF member": "us_sif_member",
    "Fund profile: Oldest shareclass inception date": "inception_date",
    "Fund profile: Portfolio holdings as-of date": "holdings_date",
    "Fund profile: Fund net assets": "net_assets",
    "Fund profile: Percent rated": "percent_rated",
    
    "Fossil Free Funds: Fossil fuel grade": "fossil_fuel_grade",
    "Fossil Free Funds: Fossil fuel holdings, count": "fossil_holdings_count",
    "Fossil Free Funds: Fossil fuel holdings, weight": "fossil_holdings_weight",
    "Fossil Free Funds: Fossil fuel holdings, asset": "fossil_holdings_asset",
    
    "Fossil Free Funds: Coal industry, count": "coal_count",
    "Fossil Free Funds: Coal industry, weight": "coal_weight",
    "Fossil Free Funds: Coal industry, asset": "coal_asset",
    
    "Fossil Free Funds: Oil / gas industry, count": "oil_gas_count",
    "Fossil Free Funds: Oil / gas industry, weight": "oil_gas_weight",
    "Fossil Free Funds: Oil / gas industry, asset": "oil_gas_asset",
    
    "Fossil Free Funds: Fossil-fired utilities, count": "utilities_count",
    "Fossil Free Funds: Fossil-fired utilities, weight": "utilities_weight",
    "Fossil Free Funds: Fossil-fired utilities, asset": "utilities_asset",
    
    "Fossil Free Funds: Fossil fuel finance grade": "fossil_finance_grade",
    "Fossil Free Funds: Fossil fuel finance fund score": "fossil_finance_score",
    "Fossil Free Funds: Fossil fuel finance holdings, count": "fossil_finance_count",
    "Fossil Free Funds: Fossil fuel finance holdings, weight": "fossil_finance_weight",
    "Fossil Free Funds: Fossil fuel finance holdings, asset": "fossil_finance_asset",
    
    "Fossil Free Funds: Fossil fuel insurance grade": "fossil_insurance_grade",
    "Fossil Free Funds: Fossil fuel insurance fund score": "fossil_insurance_score",
    "Fossil Free Funds: Fossil fuel insurance holdings, count": "fossil_insurance_count",
    "Fossil Free Funds: Fossil fuel insurance holdings, weight": "fossil_insurance_weight",
    "Fossil Free Funds: Fossil fuel insurance holdings, asset": "fossil_insurance_asset",
    
    "Fossil Free Funds: Clean200, count": "clean200_count",
    "Fossil Free Funds: Clean200, weight": "clean200_weight",
    "Fossil Free Funds: Clean200, asset": "clean200_asset",
    
    "Deforestation Free Funds: Deforestation grade": "deforestation_grade",
    "Deforestation Free Funds: Deforestation-risk producer, count": "deforestation_producer_count",
    "Deforestation Free Funds: Deforestation-risk producer, weight": "deforestation_producer_weight",
    "Deforestation Free Funds: Deforestation-risk producer, asset": "deforestation_producer_asset",
    "Deforestation Free Funds: Deforestation-risk financier, count": "deforestation_financier_count",
    "Deforestation Free Funds: Deforestation-risk financier, weight": "deforestation_financier_weight",
    "Deforestation Free Funds: Deforestation-risk financier, asset": "deforestation_financier_asset",
    "Deforestation Free Funds: Deforestation-risk consumer brand, count": "deforestation_consumer_count",
    "Deforestation Free Funds: Deforestation-risk consumer brand, weight": "deforestation_consumer_weight",
    "Deforestation Free Funds: Deforestation-risk consumer brand, asset": "deforestation_consumer_asset",
    
    "Gender Equality Funds: Gender equality grade": "gender_grade",
    "Gender Equality Funds: Gender equality group ranking": "gender_group_rank",
    "Gender Equality Funds: Gender equality score - Overall score (out of 100 points)": "gender_overall_score",
    "Gender Equality Funds: Gender equality score - Gender balance in leadership and workforce (out of 40 points)": "gender_leadership_score",
    "Gender Equality Funds: Gender equality score - Equal compensation and work life balance (out of 30 points)": "gender_compensation_score",
    "Gender Equality Funds: Gender equality score - Policies promoting gender equality (out of 20 points)": "gender_policies_score",
    "Gender Equality Funds: Gender equality score - Commitment, transparency, and accountability (out of 10 points)": "gender_commitment_score",
    "Gender Equality Funds: Count of holdings with Equileap gender equality scores": "gender_holdings_count",
    "Gender Equality Funds: Weight of holdings with Equileap gender equality scores": "gender_holdings_weight",
    
    "Gun Free Funds: Civilian firearm grade": "gun_civilian_grade",
    "Gun Free Funds: Civilian firearm, count": "gun_civilian_count",
    "Gun Free Funds: Civilian firearm, weight": "gun_civilian_weight",
    "Gun Free Funds: Civilian firearm, asset": "gun_civilian_asset",
    "Gun Free Funds: Gun manufacturer, count": "gun_manufacturer_count",
    "Gun Free Funds: Gun manufacturer, weight": "gun_manufacturer_weight",
    "Gun Free Funds: Gun manufacturer, asset": "gun_manufacturer_asset",
    "Gun Free Funds: Gun retailer, count": "gun_retailer_count",
    "Gun Free Funds: Gun retailer, weight": "gun_retailer_weight",
    "Gun Free Funds: Gun retailer, asset": "gun_retailer_asset",
    
    "Prison Free Funds: Prison industrial complex grade": "prison_grade",
    "Prison Free Funds: All flagged, count": "prison_flagged_count",
    "Prison Free Funds: All flagged, weight": "prison_flagged_weight",
    "Prison Free Funds: All flagged, asset": "prison_flagged_asset",
    "Prison Free Funds: Prison industry, count": "prison_industry_count",
    "Prison Free Funds: Prison industry, weight": "prison_industry_weight",
    "Prison Free Funds: Prison industry, asset": "prison_industry_asset",
    "Prison Free Funds: Border industry, count": "prison_border_count",
    "Prison Free Funds: Border industry, weight": "prison_border_weight",
    "Prison Free Funds: Border industry, asset": "prison_border_asset",
    "Prison Free Funds: All flagged, higher risk, count": "prison_higher_flagged_count",
    "Prison Free Funds: All flagged, higher risk, weight": "prison_higher_flagged_weight",
    "Prison Free Funds: All flagged, higher risk, asset": "prison_higher_flagged_asset",
    "Prison Free Funds: Prison industry, higher risk, count": "prison_higher_industry_count",
    "Prison Free Funds: Prison industry, higher risk, weight": "prison_higher_industry_weight",
    "Prison Free Funds: Prison industry, higher risk, asset": "prison_higher_industry_asset",
    "Prison Free Funds: Border industry, higher risk, count": "prison_higher_border_count",
    "Prison Free Funds: Border industry, higher risk, weight": "prison_higher_border_weight",
    "Prison Free Funds: Border industry, higher risk, asset": "prison_higher_border_asset",
    "Prison Free Funds: Private prison operators, count": "prison_private_count",
    "Prison Free Funds: Private prison operators, weight": "prison_private_weight",
    "Prison Free Funds: Private prison operators, asset": "prison_private_asset",
    
    "Weapon Free Funds: Military weapon grade": "weapon_military_grade",
    "Weapon Free Funds: Military contractors, count": "weapon_military_contractors_count",
    "Weapon Free Funds: Military contractors, weight": "weapon_military_contractors_weight",
    "Weapon Free Funds: Military contractors, asset": "weapon_military_contractors_asset",
    "Weapon Free Funds: Nuclear weapons, count": "weapon_nuclear_count",
    "Weapon Free Funds: Nuclear weapons, weight": "weapon_nuclear_weight",
    "Weapon Free Funds: Nuclear weapons, asset": "weapon_nuclear_asset",
    "Weapon Free Funds: Controversial weapons, count": "weapon_controversial_count",
    "Weapon Free Funds: Controversial weapons, weight": "weapon_controversial_weight",
    "Weapon Free Funds: Controversial weapons, asset": "weapon_controversial_asset",
    
    "Tobacco Free Funds: Tobacco grade": "tobacco_grade",
    "Tobacco Free Funds: Tobacco producer, count": "tobacco_producer_count",
    "Tobacco Free Funds: Tobacco producer, weight": "tobacco_producer_weight",
    "Tobacco Free Funds: Tobacco producer, asset": "tobacco_producer_asset",
    "Tobacco Free Funds: Tobacco-promoting entertainment company, count": "tobacco_entertainment_count",
    "Tobacco Free Funds: Tobacco-promoting entertainment company, weight": "tobacco_entertainment_weight",
    "Tobacco Free Funds: Tobacco-promoting entertainment company, asset": "tobacco_entertainment_asset"
}

df = df.rename(columns=simple_mapping)
print("Updated columns:")
print(df.columns.tolist())
# Out:
# Updated columns:
# ...

# %%
df.head()
# Out:
#                                  fund_name              tickers asset_manager  \
# 0  1290 Avantis U.S. Large Cap Growth Fund         TNRAX, TNXIX    1290 Funds
# 1         1290 Essex Small Cap Growth Fund  ESCFX, ESCJX, ESCKX    1290 Funds
# 2      1290 GAMCO Small/Mid Cap Value Fund  TNVAX, TNVIX, TNVRX    1290 Funds
# 3                1290 Retirement 2025 Fund                TNJIX    1290 Funds
# 4                1290 Retirement 2030 Fund                TNKIX    1290 Funds
#
#   target_date          category sustainability_mandate us_sif_member  \
# 0         NaN  U.S. Equity Fund                    NaN           NaN
# 1         NaN  U.S. Equity Fund                    NaN           NaN
# 2         NaN  U.S. Equity Fund                    NaN           NaN
# 3           Y  Allocation Funds                    NaN           NaN
# 4           Y  Allocation Funds                    NaN           NaN
#
#   inception_date holdings_date  net_assets  ...  weapon_controversial_count  \
# ...

# %%
# 3.2 Convert Money-Related Columns to Numeric
money_cols = [col for col in df.columns if ("net_assets" in col) or col.endswith("_asset")]
print("Money-related columns to convert:", money_cols)

# Loop over each money column and format it
for col in money_cols:
    df[col] = df[col].replace({'US\$': '', ',': ''}, regex=True)
    df[col] = pd.to_numeric(df[col], errors='coerce')
    # Show the first few values after conversion for confirmation
    print(f"Column '{col}' after conversion:")
    print(df[col].head(), "\n")
# Out:
# Money-related columns to convert: ['net_assets', 'fossil_holdings_asset', 'coal_asset', 'oil_gas_asset', 'utilities_asset', 'fossil_finance_asset', 'fossil_insurance_asset', 'clean200_asset', 'deforestation_producer_asset', 'deforestation_financier_asset', 'deforestation_consumer_asset', 'gun_civilian_asset', 'gun_manufacturer_asset', 'gun_retailer_asset', 'prison_flagged_asset', 'prison_industry_asset', 'prison_border_asset', 'prison_higher_flagged_asset', 'prison_higher_industry_asset', 'prison_higher_border_asset', 'prison_private_asset', 'weapon_military_contractors_asset', 'weapon_nuclear_asset', 'weapon_controversial_asset', 'tobacco_producer_asset', 'tobacco_entertainment_asset']
# Column 'net_assets' after conversion:
# 0    183704389
# 1     73076572
# 2    171793187
# 3     17263954
# 4     12258302
# Name: net_assets, dtype: int64
#
# Column 'fossil_holdings_asset' after conversion:
# 0    5608961
# 1    2495465
# 2    8569056
# 3    1020395
# 4     859047
# ...

# %%
print(df.columns.tolist())
# Out:
# ['fund_name', 'tickers', 'asset_manager', 'target_date', 'category', 'sustainability_mandate', 'us_sif_member', 'inception_date', 'holdings_date', 'net_assets', 'percent_rated', 'fossil_fuel_grade', 'fossil_holdings_count', 'fossil_holdings_weight', 'fossil_holdings_asset', 'coal_count', 'coal_weight', 'coal_asset', 'oil_gas_count', 'oil_gas_weight', 'oil_gas_asset', 'utilities_count', 'utilities_weight', 'utilities_asset', 'fossil_finance_grade', 'fossil_finance_score', 'fossil_finance_count', 'fossil_finance_weight', 'fossil_finance_asset', 'fossil_insurance_grade', 'fossil_insurance_score', 'fossil_insurance_count', 'fossil_insurance_weight', 'fossil_insurance_asset', 'clean200_count', 'clean200_weight', 'clean200_asset', 'deforestation_grade', 'deforestation_producer_count', 'deforestation_producer_weight', 'deforestation_producer_asset', 'deforestation_financier_count', 'deforestation_financier_weight', 'deforestation_financier_asset', 'deforestation_consumer_count', 'deforestat
# ...

# %%
# 4. ESG Fund Filtering
df['is_esg'] = (df['sustainability_mandate'].fillna('') == 'Y') | (df['us_sif_member'].fillna('') == 'Y')
print("Number of ESG funds:", df['is_esg'].sum())
df_esg = df[df['is_esg']]
df_esg[['fund_name', 'sustainability_mandate', 'us_sif_member']].head()
# Out:
# Number of ESG funds: 447
#                                   fund_name sustainability_mandate  \
# 13   1919 Socially Responsive Balanced Fund                      Y
# 27                    ALPS Clean Energy ETF                      Y
# 42                ALPS/Kotak India ESG Fund                      Y
# 54     AMG Boston Common Global Impact Fund                      Y
# 103              AXS Change Finance ESG ETF                      Y
#
#     us_sif_member
# 13              Y
# 27            NaN
# 42            NaN
# 54            NaN
# 103             Y

# %%
# 6. Analysis by Fund Category
esg_by_category = df.groupby("category")['is_esg'].sum().sort_values(ascending=False)
print(esg_by_category)
# Out:
# category
# U.S. Equity Fund              175
# International Equity Funds    145
# Sector Equity Funds            72
# Allocation Funds               55
# Name: is_esg, dtype: int64

# %%
plt.figure(figsize=(10,6))
esg_by_category.plot(kind='bar')
plt.title("Number of ESG Funds by Category")
plt.xlabel("Fund Category")
plt.ylabel("ESG Fund Count")
plt.tight_layout()
plt.show()

# %%
# 7. Net Assets Distribution
plt.figure(figsize=(10,6))
plt.hist(df['net_assets'].dropna(), bins=30)
plt.title("Distribution of Fund Net Assets")
plt.xlabel("Net Assets (USD)")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %%
# 8. Fund Inception Year Trend Analysis
df['inception_date'] = pd.to_datetime(df['inception_date'], errors='coerce')
df['inception_year'] = df['inception_date'].dt.year
inception_counts = df['inception_year'].value_counts().sort_index()
print(inception_counts)
# Out:
# inception_year
# 1924      1
# 1928      2
# 1929      2
# 1930      1
# 1931      3
#        ...
# 2021    267
# 2022    234
# 2023    264
# 2024    230
# 2025      9
# Name: count, Length: 93, dtype: int64

# %%
plt.figure(figsize=(10,6))
inception_counts.plot(kind='bar')
plt.title("Number of Funds Established per Year")
plt.xlabel("Year")
plt.ylabel("Fund Count")
plt.tight_layout()
plt.show()

# %%
# 9. Fossil Fuel Exposure Analysis Example
if "fossil_holdings_weight" in df.columns:
    df['fossil_holdings_weight'] = pd.to_numeric(df["fossil_holdings_weight"], errors='coerce')
    plt.figure(figsize=(10,6))
    plt.hist(df['fossil_holdings_weight'].dropna(), bins=30)
    plt.title("Distribution of Fossil Fuel Holdings Weight")
    plt.xlabel("Holdings Weight (%)")
    plt.ylabel("Frequency")
    plt.tight_layout()
    plt.show()
else:
    print("The dataset does not contain the column 'fossil_holdings_weight'.")

# %%
df.to_csv("exported_data.csv", index=False)
